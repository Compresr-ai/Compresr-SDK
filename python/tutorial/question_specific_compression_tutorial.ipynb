# %% [markdown]
# # Question-Specific Compression Tutorial
#
# Learn how to compress context **based on a specific question** for optimal relevance.
#
# ## Model: latte_v1
#
# | Parameter | Values | Description |
# |-----------|--------|-------------|
# | **model** | `latte_v1` | Query-specific compression |
# | **coarse** | `False` (default) | Token-level |
# | **coarse** | `True` | Paragraph-level |
#
# ### Compression Ratio
#
# The `target_compression_ratio` controls how aggressively to compress:
#
# | Value | Meaning | Example |
# |-------|---------|---------|
# | `0.5` | Keep 50% of tokens | 1000 → 500 tokens |
# | `0.3` | Keep 30% of tokens | 1000 → 300 tokens |
# | `2` | 2x compression (= 0.5) | 1000 → 500 tokens |
# | `4` | 4x compression (= 0.25) | 1000 → 250 tokens |
#
# - **0 < ratio ≤ 1**: Percentage of tokens to keep (0.5 = keep 50%)
# - **ratio > 1**: Compression multiplier (2 = 2x compression = keep 50%)
#
# ### Key Points:
# - **Token-level (coarse=False)**: Keeps individual relevant tokens
# - **Paragraph-level (coarse=True)**: Faster, keeps/removes entire paragraphs
# - **query**: Required - the question to preserve relevance for

# %%
# %pip install -e ../ python-dotenv
# Out:
# Obtaining file:///Users/oussama/Documents/Cmprsr/codebase/Compresr-SDK-Private/python
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for compresr (pyproject.toml) ... done
#   Created wheel for compresr: filename=compresr-2.0.4-0.editable-py3-none-any.whl size=5715 sha256=e87dd7eca6f41b7c7d3f76edb4369c9ab763db22ed10fc15c9c62d5dd18324f2
#   Stored in directory: /private/var/folders/g4/rzc_8mgd15n5f0l73k0mm3600000gn/T/pip-ephem-wheel-cache-9gpl2al7/wheels/b8/66/33/38ffb0bd34b6589c6f5f9d07abdc3fcffb34736427d2cdac72
# Successfully built compresr
# ...
#   Attempting uninstall: compresr
#     Found existing installation: compresr 2.0.4
#     Uninstalling compresr-2.0.4:
#       Successfully uninstalled compresr-2.0.4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from compresr import CompressionClient

load_dotenv("../../.env")
client = CompressionClient(api_key=os.getenv("COMPRESR_API_KEY"))
print("Client ready!")
# Out:
# Client ready!

# %% [markdown]
# ## Basic Compression (Token-Level)

# %%
# Longer context with multiple paragraphs
context = """
Machine learning is a subset of artificial intelligence that enables computer 
systems to learn and improve from experience without being explicitly programmed.
It focuses on developing algorithms that can access data and use it to learn.

Natural language processing (NLP) is another branch of AI that deals with the 
interaction between computers and humans using natural language. Modern NLP 
systems use transformer architectures like BERT, GPT, and T5 to understand 
and generate human-like text.

Computer vision enables machines to interpret and understand visual information 
from the world. It uses convolutional neural networks (CNNs) to process images 
and videos for tasks like object detection and facial recognition.

Reinforcement learning is a type of machine learning where an agent learns to 
make decisions by taking actions in an environment to maximize cumulative reward.
It's used in robotics, game playing, and autonomous systems.
"""

query = "What is machine learning?"

response = client.compress(
    context=context.strip(),
    query=query,
    compression_model_name="latte_v1",
    coarse=False,  # Token-level
)

print(f"Query: {query}")
print(f"Original: {response.data.original_tokens} tokens")
print(f"Compressed: {response.data.compressed_tokens} tokens")
print(f"Ratio: {response.data.compressed_tokens/response.data.original_tokens:.1%}")
print(f"\nResult:\n{response.data.compressed_context}")
# Out:
# Query: What is machine learning?
# Original: 174 tokens
# Compressed: 87 tokens
# Ratio: 50.0%
#
# Result:
# Machine learning is a subset of artificial intelligence that enables computer
# systems to learn and improve from experience without being explicitly programmed.
# It focuses on developing algorithms that can access data and use it to learn.
#
# Natural language processing (NLP) is another branch of AI that deals with the facial recognition.
#
# Reinforcement learning is of machine learning agent learns to
# make cumulative reward.
# It's used in robotics, game playing, and autonomous systems.

# %% [markdown]
# ## Paragraph-Level (coarse=True) - Faster

# %%
response = client.compress(
    context=context,
    query=query,
    compression_model_name="latte_v1",
    coarse=True,
)
print(f"Coarse result: {response.data.compressed_context}")
# Out:
# Coarse result:
# Machine learning is a subset of artificial intelligence that enables computer
# systems to learn and improve from experience without being explicitly programmed.
# It focuses on developing algorithms that can access data and use it to learn.
#
# Natural language processing (NLP) is another branch of AI that deals with the
# interaction between computers and humans using natural language. Modern NLP
# systems use transformer architectures like BERT, GPT, and T5 to understand
# and generate human-like text.
#
# [... 2 paragraphs filtered ...]

# %% [markdown]
# ## Structured Data: Markdown Documents
#
# Compressing markdown documentation while preserving relevant sections.

# %%
# Markdown document
md_context = """
# Project Documentation

## Overview
This project implements a machine learning pipeline for text classification.

## Installation
```bash
pip install -r requirements.txt
```

## Usage
Import the classifier and load your model:
```python
from classifier import TextClassifier
model = TextClassifier.load("model.pt")
```

## API Reference

### TextClassifier.predict(text)
Returns the predicted class for the input text.

### TextClassifier.train(dataset)
Trains the model on the provided dataset.

## Contributing
Please read CONTRIBUTING.md for guidelines.
"""

query = "How do I install the project?"

response = client.compress(
    context=md_context.strip(),
    query=query,
    compression_model_name="latte_v1",
    coarse=True,  # Paragraph-level works well for markdown
)

print(f"Query: {query}")
print(f"Original: {response.data.original_tokens} tokens")
print(f"Compressed: {response.data.compressed_tokens} tokens")
print(f"\nResult:\n{response.data.compressed_context}")
# Out:
# Query: How do I install the project?
# Original: 110 tokens
# Compressed: 85 tokens
#
# Result:
# # Project Documentation
#
# <!-- [... sections filtered: Overview (~22 tokens)] -->
#
# ## Installation
#
# ```bash
# pip install -r requirements.txt
# ```
#
# ## Usage
#
# Import the classifier and load your model:
# ```python
# from classifier import TextClassifier
# model = TextClassifier.load("model.pt")
# ```
#
# <!-- [... sections filtered: API Reference (~4 tokens)] -->
#
# ## Contributing
#
# Please read CONTRIBUTING.md for guidelines.

# %% [markdown]
# ## Structured Data: JSON
#
# Extracting relevant fields from JSON data based on a query.

# %%
# JSON structured data
import json

json_data = {
    "company": "TechCorp",
    "employees": [
        {"name": "Alice", "role": "Engineer", "department": "ML", "salary": 120000},
        {"name": "Bob", "role": "Designer", "department": "UX", "salary": 95000},
        {"name": "Carol", "role": "Manager", "department": "ML", "salary": 150000},
        {"name": "David", "role": "Engineer", "department": "Backend", "salary": 115000}
    ],
    "departments": ["ML", "UX", "Backend", "Frontend"],
    "founded": 2015,
    "headquarters": "San Francisco"
}

json_context = json.dumps(json_data, indent=2)
query = "Who works in the ML department?"

response = client.compress(
    context=json_context,
    query=query,
    compression_model_name="latte_v1",
    coarse=True,
)

print(f"Query: {query}")
print(f"Original: {response.data.original_tokens} tokens")
print(f"Compressed: {response.data.compressed_tokens} tokens")
print(f"\nResult:\n{response.data.compressed_context}")
# Out:
# Query: Who works in the ML department?
# Original: 193 tokens
# Compressed: 118 tokens
#
# Result:
# {
# "company": "TechCorp",
# "employees": [
# {
#   "name": "Alice",
#   "role": "Engineer",
#   "department": "ML",
#   "salary": 120000
# },
# {
#   "name": "Bob",
#   "role": "Designer",
#   "department": "UX",
#   "salary": 95000
# },
# "// [... 2 entries filtered]"
# ],
# "departments": [
# "ML",
# "UX",
# "Backend",
# "Frontend"
# ],
# "founded": 2015,
# "headquarters": "San Francisco"
# }

# %% [markdown]
# ## Target Compression Ratio Examples
#
# Control how aggressively to compress with `target_compression_ratio`:
# - **0.3** → Keep 30%, remove 70% (aggressive)
# - **0.5** → Keep 50%, remove 50% (balanced)
# - **0.7** → Keep 70%, remove 30% (light)
# - **2** → 2x compression = keep 50%
# - **4** → 4x compression = keep 25%

# %%
# Test different compression ratios with a longer context
test_context = """
Machine learning is a transformative subset of artificial intelligence that enables 
computer systems to automatically learn and improve from experience without being 
explicitly programmed. At its core, machine learning focuses on the development of 
algorithms and statistical models that allow computers to perform specific tasks 
by relying on patterns and inference rather than explicit instructions.

The field encompasses several major paradigms. Supervised learning uses labeled 
training data to learn a mapping from inputs to outputs, commonly used for 
classification and regression tasks. Unsupervised learning finds hidden patterns 
in unlabeled data through clustering and dimensionality reduction techniques.
Semi-supervised learning combines both approaches when labeled data is scarce.

Deep learning represents a powerful subset of machine learning that uses artificial 
neural networks with multiple hidden layers. These deep networks can automatically 
learn hierarchical representations of data, enabling breakthroughs in image recognition, 
natural language processing, and speech recognition. Convolutional neural networks 
excel at processing grid-like data such as images, while recurrent neural networks 
handle sequential data like text and time series.

Natural language processing (NLP) applies machine learning to understand and generate 
human language. Modern NLP systems leverage transformer architectures like BERT, GPT, 
and T5 to achieve state-of-the-art performance on tasks including sentiment analysis, 
named entity recognition, question answering, and machine translation.

Computer vision enables machines to interpret and understand visual information from 
images and videos. Applications include object detection, facial recognition, medical 
image analysis, and autonomous vehicle navigation. These systems often combine CNNs 
with attention mechanisms for improved accuracy.

Reinforcement learning trains agents to make sequential decisions by interacting with 
an environment and receiving rewards or penalties. This paradigm has achieved remarkable 
success in game playing, robotics control, and resource optimization problems.
"""
test_query = "What is machine learning?"

print("Testing Different Compression Ratios\n")
print(f"Original context: {len(test_context.split())} words\n")

for ratio in [0.3, 0.5, 0.7, 2, 4]:
    response = client.compress(
        context=test_context.strip(),
        query=test_query,
        compression_model_name="latte_v1",
        target_compression_ratio=ratio,
    )
    
    # Show ratio interpretation
    if ratio <= 1:
        desc = f"keep {ratio*100:.0f}%"
    else:
        desc = f"{ratio}x compression = keep {100/ratio:.0f}%"
    
    print(f"Ratio {ratio} ({desc}):")
    print(f"  {response.data.original_tokens} → {response.data.compressed_tokens} tokens")
    print(f"  Actual: {response.data.compressed_tokens/response.data.original_tokens:.1%}")
    print(f"  Result: {response.data.compressed_context[:100]}...\n")
# Out:
# Testing Different Compression Ratios
#
# Original context: 280 words
#
# Ratio 0.3 (keep 30%):
#   362 → 108 tokens
#   Actual: 29.8%
#   Result: Machine learning is a transformative subset of artificial intelligence that enables
# computer system...
#
# Ratio 0.5 (keep 50%):
#   362 → 181 tokens
#   Actual: 50.0%
#   Result: Machine learning is a transformative subset of artificial intelligence that enables
# computer system...
#
# Ratio 0.7 (keep 70%):
#   362 → 253 tokens
#   Actual: 69.9%
#   Result: Machine learning is a transformative subset of artificial intelligence that enables
# computer system...
#
# Ratio 2 (2x compression = keep 50%):
#   362 → 181 tokens
#   Actual: 50.0%
#   Result: Machine learning is a transformative subset of artificial intelligence that enables
# computer system...
#
# Ratio 4 (4x compression = keep 25%):
#   362 → 90 tokens
#   Actual: 24.9%
#   Result: Machine learning is a transformative subset of artificial intelligence that enables
# ...

# %% [markdown]
# ## Async Compression
#
# Use `compress_async()` for non-blocking compression in async workflows.

# %%
async def compress_async_demo():
    context = """
    Quantum computing represents a revolutionary paradigm in computational technology 
    that harnesses the principles of quantum mechanics to process information in 
    fundamentally different ways than classical computers. Unlike traditional bits 
    that exist as either 0 or 1, quantum bits (qubits) can exist in superposition, 
    representing both states simultaneously until measured.
    
    The phenomenon of quantum entanglement allows qubits to be correlated in ways 
    that have no classical analog, enabling quantum computers to perform certain 
    calculations exponentially faster than their classical counterparts. This 
    quantum advantage is particularly relevant for problems involving optimization, 
    simulation of quantum systems, and cryptographic applications.
    
    Major technology companies and research institutions are racing to develop 
    practical quantum computers. IBM, Google, and various startups have demonstrated 
    quantum supremacy for specific tasks. Applications include drug discovery through 
    molecular simulation, financial modeling, supply chain optimization, and breaking 
    current encryption standards while enabling quantum-safe cryptography.
    
    However, quantum computers face significant challenges including decoherence, 
    error rates, and the need for extremely low operating temperatures. Current 
    systems require sophisticated error correction and are primarily available 
    through cloud-based quantum computing services.
    """
    query = "What is quantum computing?"
    
    response = await client.compress_async(
        context=context.strip(),
        query=query,
        compression_model_name="latte_v1",
        target_compression_ratio=0.5,
    )
    
    print("Async compression complete!")
    print(f"Tokens: {response.data.original_tokens} → {response.data.compressed_tokens}")
    print(f"Actual ratio: {response.data.compressed_tokens/response.data.original_tokens:.1%}")
    print(f"\nResult:\n{response.data.compressed_context}")

await compress_async_demo()
# Out:
# Async compression complete!
# Tokens: 244 → 122
# Actual ratio: 50.0%
#
# Result:
# Quantum computing represents a revolutionary paradigm in computational technology
#     that harnesses the principles of quantum mechanics to process information in
#     fundamentally different ways than classical computers. Unlike traditional bits
#     that exist as either 0 or 1, quantum can exist in superposition,
#     representing both states simultaneously until measured.
#
#     The phenomenon of quantum entanglement correlated in ways and breaking
#     current encryption standards while enabling quantum-safe cryptography.
#
#     However, quantum computers face significant challenges including decoherence,
#     error rates, and sophisticated error correction and are primarily available
#     through cloud-based quantum computing services.

# %% [markdown]
# ## Batch Processing
#
# Compress multiple contexts efficiently in a single API call.
#
# The `compress_batch()` method supports two modes:
# - **Same query**: Pass a single query string for all contexts
# - **Different queries**: Pass a list of queries (one per context)
#
# ### Option 1: Same Query for All Contexts
#
# Useful when searching for the same information across multiple documents.

# %%
# Three documents about different ML topics
contexts = [
    """Machine learning is a transformative field of artificial intelligence that enables 
    computer systems to automatically learn and improve from experience without being 
    explicitly programmed. At its foundation, machine learning focuses on developing 
    algorithms that can access data and use it to learn for themselves. The technology 
    powers recommendation systems at Netflix and Spotify, fraud detection at banks, 
    predictive maintenance in manufacturing, and personalized medicine in healthcare.
    Companies leverage ML for customer segmentation, churn prediction, and demand 
    forecasting to make data-driven decisions that improve business outcomes.""",
    
    """Deep learning represents a powerful subset of machine learning built on artificial 
    neural networks with multiple hidden layers. These architectures can automatically 
    learn hierarchical representations of data, enabling breakthroughs across many domains.
    Convolutional Neural Networks (CNNs) have revolutionized computer vision, powering 
    facial recognition, medical imaging diagnosis, and autonomous vehicle perception.
    Recurrent Neural Networks (RNNs) and LSTMs handle sequential data for speech 
    recognition, language translation, and time series forecasting. More recently, 
    Transformer architectures have dominated natural language processing, enabling 
    large language models like GPT and BERT to understand and generate human-like text.""",
    
    """Reinforcement learning trains intelligent agents through trial and error by 
    interacting with an environment and receiving rewards or penalties for their actions.
    This paradigm has achieved remarkable successes: DeepMind's AlphaGo defeated world 
    champions at Go, AlphaStar reached Grandmaster level in StarCraft II, and OpenAI Five 
    beat professional Dota 2 teams. Beyond games, RL powers robotics applications for 
    manipulation and locomotion, optimizes data center cooling at Google, manages 
    traffic signals in cities, and enables autonomous vehicles to navigate complex 
    scenarios. The combination of deep learning with RL (Deep RL) has unlocked new 
    capabilities in decision-making systems that learn from experience.""",
]

# Same query for all documents
query = "What are the real-world applications?"

response = client.compress_batch(
    contexts=contexts,
    queries=query,  # Single query applied to all contexts
    compression_model_name="latte_v1",
    target_compression_ratio=0.5,
)

print(f"Batch compression: {len(response.data.results)} contexts")
print(f"Total tokens saved: {response.data.total_tokens_saved}")
print(f"Average compression: {response.data.average_compression_ratio:.1%}\n")

for i, result in enumerate(response.data.results):
    print(f"Context {i+1}:")
    print(f"  {result.original_tokens} → {result.compressed_tokens} tokens")
    print(f"  Result: {result.compressed_context[:120]}...\n")
# Out:
# Batch compression: 3 contexts
# Total tokens saved: 183
# Average compression: 47.7%
#
# Context 1:
#   109 → 64 tokens
#   Result: Machine learning is a transformative field of artificial intelligence that enables
#     computer systems at Netflix and ...
#
# Context 2:
#   135 → 67 tokens
#   Result: Deep learning represents a powerful subset of machine learning built on artificial
#  have revolutionized computer vision...
#
# Context 3:
#   140 → 70 tokens
#   Result: Reinforcement beat professional Dota 2 teams. Beyond games, RL powers robotics applications for
#     manipulation and lo...

# %% [markdown]
# ### Option 2: Different Query per Context
#
# When each document has a specific question, pass a list of queries matching the contexts.

# %%
# Same contexts as before, but with different questions for each
different_queries = [
    "What is machine learning and how is it used in business?",
    "What neural network architectures power deep learning?",
    "How has reinforcement learning succeeded in games and robotics?",
]

response = client.compress_batch(
    contexts=contexts,
    queries=different_queries,  # One query per context
    compression_model_name="latte_v1",
    coarse=True,  # Paragraph-level for faster processing
)

print(f"Batch with different queries: {len(response.data.results)} contexts\n")

for i, (result, q) in enumerate(zip(response.data.results, different_queries)):
    print(f"Context {i+1}: '{q[:40]}...'")
    print(f"  {result.original_tokens} → {result.compressed_tokens} tokens")
    print(f"  Result: {result.compressed_context[:100]}...\n")
# Out:
# Batch with different queries: 3 contexts
#
# Context 1: 'What is machine learning and how is it u...'
#   109 → 109 tokens
#   Result: Machine learning is a transformative field of artificial intelligence that enables
#     computer sys...
#
# Context 2: 'What neural network architectures power ...'
#   135 → 135 tokens
#   Result: Deep learning represents a powerful subset of machine learning built on artificial
#     neural netwo...
#
# Context 3: 'How has reinforcement learning succeeded...'
#   140 → 140 tokens
#   Result: Reinforcement learning trains intelligent agents through trial and error by
#     interacting with an...

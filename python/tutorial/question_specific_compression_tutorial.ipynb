# %% [markdown]
# # Question-Specific Compression Tutorial
#
# Learn how to compress context based on a specific question for optimal relevance.
#
# Use **QSCompressionClient** for question-specific compression with models:
# - **QS_CMPRSR_V1** - Question-specific compression (recommended)
# - **QSR_CMPRSR_V1** - Question-specific with reranking
# - **QSLF_CMPRSR_V1** - Question-specific with longformer

# %% [markdown]
# ## 1. Installation

# %%
# %pip install compresr python-dotenv --upgrade

# %% [markdown]
# ## 2. Setup

# %%
import os
from dotenv import load_dotenv
from compresr import QSCompressionClient

# Load environment variables from parent folder
env_path = "../../.env"
load_dotenv(env_path)

# Option 1: Set your API key directly
# api_key = "cmp_your_api_key_here"

# Option 2: Use environment variable (recommended)
api_key = os.getenv("COMPRESR_API_KEY")

# Initialize client - uses https://api.compresr.ai by default
client = QSCompressionClient(api_key=api_key)

print("✅ Client initialized!")
if api_key:
    print(f"🔑 API key: {api_key[:12]}...")
else:
    print("⚠️  Set COMPRESR_API_KEY environment variable or pass api_key directly")
# Out:
# ✅ Client initialized!
# 🔑 API key: cmp_4pN2xWQ9...

# %% [markdown]
# ## 3. Basic Question-Specific Compression
#
# Compress a context while preserving content relevant to a specific question.

# %%
# Context with multiple topics - larger text for better compression demonstration
context = """
Machine learning is a comprehensive subset of artificial intelligence that enables computer systems 
to automatically learn and improve from experience without being explicitly programmed. It focuses 
on developing algorithms that can access data, analyze patterns, and use that information to learn 
for themselves. Deep learning is an advanced branch of machine learning that uses artificial neural 
networks with many layers to model complex patterns in large datasets. These deep neural networks 
can automatically discover the representations needed for detection or classification from raw data.

Natural language processing (NLP) is another major branch of AI that deals with the interaction 
between computers and humans using natural language. NLP technologies can analyze, understand, 
and generate human language, enabling applications like chatbots, translation services, and 
sentiment analysis. Computer vision is the field that enables machines to derive meaningful 
information from digital images, videos, and other visual inputs. It uses convolutional neural 
networks (CNNs) to process and analyze visual data for applications like facial recognition 
and autonomous vehicles.

Reinforcement learning is a type of machine learning where an agent learns to behave in an 
environment by performing actions and seeing the results. The agent receives rewards for correct 
actions and penalties for incorrect ones. Transfer learning is a technique that allows models 
trained on one task to be repurposed for a different but related task, significantly reducing 
training time and required data.
"""

# Your specific question
question = "What is machine learning and how does it work?"

# Test all available models
models = ["QS_CMPRSR_V1", "QSR_CMPRSR_V1", "QSLF_CMPRSR_V1"]

for model in models:
    print(f"\n{'='*60}")
    print(f"🤖 Testing Model: {model}")
    print('='*60)
    
    response = client.compress(
        context=context.strip(),
        question=question,
        compression_model_name=model,
        target_compression_ratio=0.5  # Remove 50% of tokens
    )
    
    print("✅ Question-specific compression successful!")
    print(f"\n❓ Question: {question}")
    print("\n📊 Results:")
    print(f"   Original tokens: {response.data.original_tokens}")
    print(f"   Compressed tokens: {response.data.compressed_tokens}")
    print(f"   Tokens saved: {response.data.tokens_saved}")
    print(f"   Compression ratio: {response.data.actual_compression_ratio:.1%}")
    print("\n📝 Compressed context (relevant to question):")
    print(response.data.compressed_context)
# Out:
# ...
# 🤖 Testing Model: QS_CMPRSR_V1
# ...
# ✅ Question-specific compression successful!
#
# ❓ Question: What is machine learning and how does it work?
#
# 📊 Results:
#    Original tokens: 287
#    Compressed tokens: 134
#    Tokens saved: 153
#    Compression ratio: 53.3%
#
# 📝 Compressed context (relevant to question):
# DEF:
# - ML ⊂ AI: systems learn/improve from experience (data) w/o explicit programming.
#
# HOW (core):
# - Build algos/models that access data → analyze patterns → update internal parameters to improve performance on a task.
#
# FACTS (related ML types/tech):
# - Deep learning: advanced ML using multi-layer artificial neural nets; learns needed representations from raw data; good for complex patterns/large datasets.
# - Reinforcement learning: agent acts in environment; gets rewards/penalties; learns behavior from outcomes.
# - Transfer learning: reuse model trained on one task for related task; reduces training time + data needed.
#
# ...
# 🤖 Testing Model: QSR_CMPRSR_V1
# ...

# %% [markdown]
# ## 4. Different Questions, Different Compressions
#
# See how the same context compresses differently based on the question.

# %%
# Same context, different questions - see how compression adapts to each question
context = """
Python is a high-level, interpreted programming language created by Guido van Rossum and first 
released in 1991. It emphasizes code readability with its use of significant indentation and 
supports multiple programming paradigms including procedural, object-oriented, and functional 
programming. Python has become one of the most popular languages for data science, machine 
learning, and web development due to its extensive library ecosystem.

JavaScript was originally created by Brendan Eich while working at Netscape Communications 
Corporation in 1995. Initially designed to add interactivity to web pages in the browser, 
JavaScript has evolved into a versatile language now used for server-side programming with 
Node.js, mobile app development, and even desktop applications. It is the backbone of modern 
web development alongside HTML and CSS.

Java was developed by James Gosling and his team at Sun Microsystems, with its first public 
release in 1995. It was designed with the principle of "write once, run anywhere" (WORA), 
meaning compiled Java code can run on any platform that supports Java without recompilation. 
Java is widely used in enterprise applications, Android mobile development, and large-scale 
distributed systems.
"""

questions = [
    "Who created Python and when?",
    "What is JavaScript used for today?",
    "What is the main principle behind Java?"
]

# Test all available models
models = ["QS_CMPRSR_V1", "QSR_CMPRSR_V1", "QSLF_CMPRSR_V1"]

for model in models:
    print(f"\n{'='*60}")
    print(f"🤖 Testing Model: {model}")
    print('='*60)
    
    for question in questions:
        response = client.compress(
            context=context.strip(),
            question=question,
            compression_model_name=model
        )
        print(f"\n❓ Question: {question}")
        print(f"📝 Compressed: {response.data.compressed_context[:100]}...")
        print(f"   ({response.data.tokens_saved} tokens saved, {response.data.actual_compression_ratio:.1%} ratio)")
# Out:
# ...
# 🤖 Testing Model: QS_CMPRSR_V1
# ...
#
# ❓ Question: Who created Python and when?
# 📝 Compressed: FACTS:
# - Python: created by **Guido van Rossum**; first released **1991**....
#    (217 tokens saved, 87.8% ratio)
#
# ❓ Question: What is JavaScript used for today?
# 📝 Compressed: FACTS:
# - JS (1995, Brendan Eich/Netscape) now used for:
#   - Browser/web-page interactivity; backbone...
#    (182 tokens saved, 73.7% ratio)
#
# ❓ Question: What is the main principle behind Java?
# 📝 Compressed: Java: main principle = **“write once, run anywhere” (WORA)** → compiled Java code runs on any platfo...
#    (205 tokens saved, 83.0% ratio)
#
# ...
# 🤖 Testing Model: QSR_CMPRSR_V1
# ...
#
# ❓ Question: Who created Python and when?
# 📝 Compressed: Python is a high-level, interpreted programming language created by Guido van Rossum and first
# rele...
#    (0 tokens saved, 0.0% ratio)
#
# ❓ Question: What is JavaScript used for today?
# ...

# %% [markdown]
# ## 5. Batch Question-Specific Compression
#
# Compress multiple context-question pairs at once. Each input has its own context and question.

# %%
# Batch compression - each input has its own context and question
# Use inputs: list of dicts with {"context": "...", "question": "..."}

inputs = [
    {
        "context": """Machine learning is a subset of artificial intelligence that enables systems to learn from data.
    It uses algorithms that improve automatically through experience and training on datasets.
    Deep learning is a specialized form of machine learning using neural networks with many layers.
    These systems can recognize patterns, make predictions, and automate complex tasks.""",
        "question": "What is machine learning?"
    },
    {
        "context": """The solar system consists of eight planets orbiting the Sun: Mercury, Venus, Earth, Mars, 
    Jupiter, Saturn, Uranus, and Neptune. Mars is called the Red Planet due to iron oxide on its surface.
    Jupiter is the largest planet and has over 80 known moons. Saturn is famous for its ring system.""",
        "question": "How many planets are in the solar system?"
    },
    {
        "context": """William Shakespeare was an English playwright born in Stratford-upon-Avon in 1564.
    He wrote approximately 39 plays including Hamlet, Macbeth, Romeo and Juliet, and Othello.
    His works have been translated into every major language and are performed more often than those of any other playwright.""",
        "question": "What plays did Shakespeare write?"
    },
]

# Test all available models
models = ["QS_CMPRSR_V1", "QSR_CMPRSR_V1", "QSLF_CMPRSR_V1"]

for model in models:
    print(f"\n{'='*60}")
    print(f"🤖 Testing Model: {model}")
    print('='*60)
    
    response = client.compress_batch(
        inputs=inputs,
        compression_model_name=model
    )
    
    print(f"✅ Compressed {len(response.data.results)} contexts")
    print(f"   Total tokens saved: {response.data.total_tokens_saved}")
    
    for i, result in enumerate(response.data.results):
        print(f"\n📝 Context {i+1}:")
        print(f"   Compressed: {result.compressed_context[:80]}...")
        print(f"   Tokens saved: {result.tokens_saved}")
# Out:
# ...
# 🤖 Testing Model: QS_CMPRSR_V1
# ...
# ✅ Compressed 3 contexts
#    Total tokens saved: 86
#
# 📝 Context 1:
#    Compressed: DEF: ML ⊂ AI; enables systems to learn from data via algorithms that improve aut...
#    Tokens saved: 10
#
# 📝 Context 2:
#    Compressed: FACTS: Solar system has 8 planets: Mercury, Venus, Earth, Mars, Jupiter, Saturn,...
#    Tokens saved: 41
#
# 📝 Context 3:
#    Compressed: FACTS:
# - Shakespeare wrote ~39 plays; examples listed: **Hamlet, Macbeth, Romeo ...
#    Tokens saved: 35
#
# ...
# 🤖 Testing Model: QSR_CMPRSR_V1
# ...
# ✅ Compressed 3 contexts
#    Total tokens saved: 0
#
# 📝 Context 1:
#    Compressed: Machine learning is a subset of artificial intelligence that enables systems to ...
#    Tokens saved: 0
#
# 📝 Context 2:
#    Compressed: The solar system consists of eight planets orbiting the Sun: Mercury, Venus, Ear...
#    Tokens saved: 0
#
# 📝 Context 3:
#    Compressed: William Shakespeare was an English playwright born in Stratford-upon-Avon in 156...
# ...

# %% [markdown]
# ## 6. Async Question-Specific Compression

# %%
async def compress_async():
    context = "Quantum computing uses qubits for computation. Classical computers use bits."
    question = "What do quantum computers use?"
    
    # Test all available models
    models = ["QS_CMPRSR_V1", "QSR_CMPRSR_V1", "QSLF_CMPRSR_V1"]
    
    for model in models:
        print(f"\n{'='*60}")
        print(f"🤖 Testing Model: {model}")
        print('='*60)
        
        response = await client.compress_async(
            context=context,
            question=question,
            compression_model_name=model
        )
        print(f"✅ Async QS compression: {response.data.tokens_saved} tokens saved")
        print(f"📝 Result: {response.data.compressed_context}")
        
    return response

# Run async
await compress_async()
# Out:
# ...
# 🤖 Testing Model: QS_CMPRSR_V1
# ...
# ✅ Async QS compression: 3 tokens saved
# 📝 Result: Quantum computers use **qubits** for computation.
#
# ...
# 🤖 Testing Model: QSR_CMPRSR_V1
# ...
# ✅ Async QS compression: 0 tokens saved
# 📝 Result: Quantum computing uses qubits for computation. Classical computers use bits.
#
# ...
# 🤖 Testing Model: QSLF_CMPRSR_V1
# ...
# ✅ Async QS compression: 0 tokens saved
# 📝 Result: Quantum computing uses qubits for computation. Classical computers use bits.
# CompressResponse(success=True, message=None, data=CompressResult(original_context='Quantum computing uses qubits for computation. Classical computers use bits.', compressed_context='Quantum computing uses qubits for computation. Classical computers use bits.', original_tokens=21, compressed_tokens=21, actual_compression_ratio=0.0, tokens_saved=0, duration_ms=76, target_compression_ratio=None))

# %% [markdown]
# ## 7. Streaming Question-Specific Compression

# %%
# Stream compressed output - Testing all models
context = """
Artificial intelligence is transforming many industries. 
Healthcare uses AI for diagnosis and drug discovery.
Finance uses AI for fraud detection and algorithmic trading.
Transportation uses AI for autonomous vehicles and route optimization.
Education uses AI for personalized learning and automated grading.
"""
question = "How is AI used in healthcare?"

# Test all available models
models = ["QS_CMPRSR_V1", "QSR_CMPRSR_V1", "QSLF_CMPRSR_V1"]

for model in models:
    print(f"\n{'='*60}")
    print(f"🤖 Testing Model: {model}")
    print('='*60)
    print(f"❓ Question: {question}")
    print("📡 Streaming compression:")
    
    for chunk in client.compress_stream(
        context=context.strip(),
        question=question,
        compression_model_name=model
    ):
        if chunk.content:
            print(chunk.content, end="", flush=True)
        if chunk.done:
            print("\n✅ Stream complete!")
# Out:
# ...
# 🤖 Testing Model: QS_CMPRSR_V1
# ...
# ❓ Question: How is AI used in healthcare?
# 📡 Streaming compression:
#
# ✅ Stream complete!
#
# ...
# 🤖 Testing Model: QSR_CMPRSR_V1
# ...
# ❓ Question: How is AI used in healthcare?
# 📡 Streaming compression:
#
# ✅ Stream complete!
#
# ...
# 🤖 Testing Model: QSLF_CMPRSR_V1
# ...
# ❓ Question: How is AI used in healthcare?
# 📡 Streaming compression:
#
# ✅ Stream complete!

# %% [markdown]
# ## 8. Error Handling

# %%
from compresr.exceptions import (
    CompresrError,
    AuthenticationError,
    RateLimitError,
    ValidationError
)

try:
    response = client.compress(
        context="Test context",
        question="What is this about?",
        compression_model_name="QS_CMPRSR_V1"
    )
    print("✅ Success!")
except AuthenticationError:
    print("❌ Invalid API key")
except RateLimitError:
    print("⏳ Rate limit exceeded, try again later")
except ValidationError as e:
    print(f"❌ Invalid input: {e}")
except CompresrError as e:
    print(f"❌ API error: {e}")
# Out:
# ✅ Success!
